# %%
import pandas as pd

# %%
population = [35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523]
countries = ['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
       'United States']

# %%
g7_dict = {
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}

# %%
g7 = pd.Series(population)

# %%
g7
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
g7.name = 'G7 population in millions'

# %%
g7
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 population in millions, dtype: float64

# %% [markdown]
# ## Indexing

# %%
lst = [1, 2, 3, 4, 5, 6, 7]

# %%
lst[0]
# Out:
# 1

# %%
lst[:2]
# Out:
# [1, 2]

# %%
lst[-3:]
# Out:
# [5, 6, 7]

# %%
lst[4:]
# Out:
# [5, 6, 7]

# %%
lst[::2]
# Out:
# [1, 3, 5, 7]

# %%
g7
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 population in millions, dtype: float64

# %%
g7[0]
# Out:
# 35.467

# %%
g7[6]
# Out:
# 318.523

# %%
g7[1:5]
# Out:
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# Name: G7 population in millions, dtype: float64

# %%
g7[[4, 2, 0, 3]]
# Out:
# 4    127.061
# 2     80.940
# 0     35.467
# 3     60.665
# Name: G7 population in millions, dtype: float64

# %%
g7[[2, 2, 4, 2, 2]]
# Out:
# 2     80.940
# 2     80.940
# 4    127.061
# 2     80.940
# 2     80.940
# Name: G7 population in millions, dtype: float64

# %%
g7.index = countries

# %%
g7
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: G7 population in millions, dtype: float64

# %%
g7['Canada']
# Out:
# 35.467

# %%
g7['France': 'Japan']
# Out:
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# Name: G7 population in millions, dtype: float64

# %%
g7[: 'United Kingdom': 2]
# Out:
# Canada      35.467
# Germany     80.940
# Japan      127.061
# Name: G7 population in millions, dtype: float64

# %%
g7[['Canada', 'Japan', 'Canada']]
# Out:
# Canada     35.467
# Japan     127.061
# Canada     35.467
# Name: G7 population in millions, dtype: float64

# %%
g7[0]
# Out:
# 35.467

# %%
g7[2]
# Out:
# 80.94

# %%
g7[1:3]
# Out:
# France     63.951
# Germany    80.940
# Name: G7 population in millions, dtype: float64

# %%
g7.iloc[0]
# Out:
# 35.467

# %%
g7.iloc[2:5]
# Out:
# Germany     80.940
# Italy       60.665
# Japan      127.061
# Name: G7 population in millions, dtype: float64

# %% [markdown]
# # DataFrame

# %%
df = pd.DataFrame(g7_dict)

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index = countries

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %%
df.shape[0]
# Out:
# 7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.describe().round(2)
# Out:
#        Population          GDP  Surface Area   HDI
# count        7.00         7.00          7.00  7.00
# mean       107.30   5080248.00    3061327.29  0.90
# std         97.25   5494020.16    4576186.57  0.02
# min         35.47   1785387.00     242495.00  0.87
# 25%         62.31   2500715.50     329225.00  0.89
# 50%         64.51   2950039.00     377930.00  0.91
# 75%        104.00   4238402.00    5082873.00  0.91
# max        318.52  17348075.00    9984670.00  0.92

# %% [markdown]
# ## DataFrame Indexing and Slicing

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.loc['Canada', 'HDI']
# Out:
# 0.913

# %%
df.loc['France': 'United States': 2]
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# France              63.951  2833687        640679  0.888    Europe
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df.loc['France': 'United States': 2, 'GDP']['Italy']
# Out:
# 2167744

# %%
df.iloc[5]
# Out:
# Population       64.511
# GDP             2950039
# Surface Area     242495
# HDI               0.907
# Continent        Europe
# Name: United Kingdom, dtype: object

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.loc[['France', 'Italy', 'France']]
# Out:
#         Population      GDP  Surface Area    HDI Continent
# France      63.951  2833687        640679  0.888    Europe
# Italy       60.665  2167744        301336  0.873    Europe
# France      63.951  2833687        640679  0.888    Europe

# %%
df.iloc[:5][['HDI', 'GDP']]
# Out:
#            HDI      GDP
# Canada   0.913  1785387
# France   0.888  2833687
# Germany  0.916  3874437
# Italy    0.873  2167744
# Japan    0.891  4602367

# %%
df.loc[:, 'Population': 'HDI']
# Out:
#                 Population       GDP  Surface Area    HDI
# Canada              35.467   1785387       9984670  0.913
# France              63.951   2833687        640679  0.888
# Germany             80.940   3874437        357114  0.916
# Italy               60.665   2167744        301336  0.873
# Japan              127.061   4602367        377930  0.891
# United Kingdom      64.511   2950039        242495  0.907
# United States      318.523  17348075       9525067  0.915

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df.GDP
# Out:
# Canada             1785387
# France             2833687
# Germany            3874437
# Italy              2167744
# Japan              4602367
# United Kingdom     2950039
# United States     17348075
# Name: GDP, dtype: int64

# %% [markdown]
# ### Drop

# %%
df.drop('Canada')
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(['Italy', 'Germany'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop('GDP', axis=1)
# Out:
#                 Population  Surface Area    HDI Continent
# Canada              35.467       9984670  0.913   America
# France              63.951        640679  0.888    Europe
# Germany             80.940        357114  0.916    Europe
# Italy               60.665        301336  0.873    Europe
# Japan              127.061        377930  0.891      Asia
# United Kingdom      64.511        242495  0.907    Europe
# United States      318.523       9525067  0.915   America

# %% [markdown]
# ## Operations

# %%
df[['Population', 'GDP']] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %%
crisis = pd.Series([-50000, -0.3], index=['GDP', 'HDI'])

# %%
crisis
# Out:
# GDP   -50000.0
# HDI       -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                        GDP    HDI
# Canada           1735387.0  0.613
# France           2783687.0  0.588
# Germany          3824437.0  0.616
# Italy            2117744.0  0.573
# Japan            4552367.0  0.591
# United Kingdom   2900039.0  0.607
# United States   17298075.0  0.615

# %% [markdown]
# ## Modyfying DataFrame

# %%
langs = pd.Series(['French', 'German', 'Italian'], index=['France', 'Germany', 'Italy'])

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# dtype: object

# %%
df['Languages'] = langs

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Languages
# Canada              35.467   1785387       9984670  0.913   America       NaN
# France              63.951   2833687        640679  0.888    Europe    French
# Germany             80.940   3874437        357114  0.916    Europe    German
# Italy               60.665   2167744        301336  0.873    Europe   Italian
# Japan              127.061   4602367        377930  0.891      Asia       NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe       NaN
# United States      318.523  17348075       9525067  0.915   America       NaN

# %%
df['GDP per capita'] = df.GDP / (df.Population * 1000000)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Languages  \
# Canada              35.467   1785387       9984670  0.913   America       NaN
# France              63.951   2833687        640679  0.888    Europe    French
# Germany             80.940   3874437        357114  0.916    Europe    German
# Italy               60.665   2167744        301336  0.873    Europe   Italian
# Japan              127.061   4602367        377930  0.891      Asia       NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe       NaN
# United States      318.523  17348075       9525067  0.915   America       NaN
#
#                 GDP per capita
# Canada                0.050339
# France                0.044310
# Germany               0.047868
# Italy                 0.035733
# Japan                 0.036222
# United Kingdom        0.045729
# United States         0.054464

# %%
df.rename(
    index={"United Kingdom": 'UK', 'United States': 'USA'},
    columns={'GDP': 'Gross Domestic Product', 'HDI': 'Human Development Index'},
    inplace=True
)

# %%
df
# Out:
#          Population  Gross Domestic Product  Surface Area  \
# Canada       35.467                 1785387       9984670
# France       63.951                 2833687        640679
# Germany      80.940                 3874437        357114
# Italy        60.665                 2167744        301336
# Japan       127.061                 4602367        377930
# UK           64.511                 2950039        242495
# USA         318.523                17348075       9525067
#
#          Human Development Index Continent Languages  GDP per capita
# Canada                     0.913   America       NaN        0.050339
# France                     0.888    Europe    French        0.044310
# Germany                    0.916    Europe    German        0.047868
# Italy                      0.873    Europe   Italian        0.035733
# Japan                      0.891      Asia       NaN        0.036222
# UK                         0.907    Europe       NaN        0.045729
# ...

# %%
df.loc['China'] = pd.Series({'Population': 1500, 'Continent': 'Asia'})

# %%
df
# Out:
#          Population  Gross Domestic Product  Surface Area  \
# Canada       35.467               1785387.0     9984670.0
# France       63.951               2833687.0      640679.0
# Germany      80.940               3874437.0      357114.0
# Italy        60.665               2167744.0      301336.0
# Japan       127.061               4602367.0      377930.0
# UK           64.511               2950039.0      242495.0
# USA         318.523              17348075.0     9525067.0
# China      1500.000                     NaN           NaN
#
#          Human Development Index Continent Languages  GDP per capita
# Canada                     0.913   America       NaN        0.050339
# France                     0.888    Europe    French        0.044310
# Germany                    0.916    Europe    German        0.047868
# Italy                      0.873    Europe   Italian        0.035733
# Japan                      0.891      Asia       NaN        0.036222
# ...

# %% [markdown]
# ## Index Changing

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index  Population  Gross Domestic Product  Surface Area  \
# 0   Canada      35.467               1785387.0     9984670.0
# 1   France      63.951               2833687.0      640679.0
# 2  Germany      80.940               3874437.0      357114.0
# 3    Italy      60.665               2167744.0      301336.0
# 4    Japan     127.061               4602367.0      377930.0
# 5       UK      64.511               2950039.0      242495.0
# 6      USA     318.523              17348075.0     9525067.0
# 7    China    1500.000                     NaN           NaN
#
#    Human Development Index Continent Languages  GDP per capita
# 0                    0.913   America       NaN        0.050339
# 1                    0.888    Europe    French        0.044310
# 2                    0.916    Europe    German        0.047868
# 3                    0.873    Europe   Italian        0.035733
# 4                    0.891      Asia       NaN        0.036222
# ...

# %%
df.set_index('index', inplace=True)

# %%
df
# Out:
#          Population  Gross Domestic Product  Surface Area  \
# index
# Canada       35.467               1785387.0     9984670.0
# France       63.951               2833687.0      640679.0
# Germany      80.940               3874437.0      357114.0
# Italy        60.665               2167744.0      301336.0
# Japan       127.061               4602367.0      377930.0
# UK           64.511               2950039.0      242495.0
# USA         318.523              17348075.0     9525067.0
# China      1500.000                     NaN           NaN
#
#          Human Development Index Continent Languages  GDP per capita
# index
# Canada                     0.913   America       NaN        0.050339
# France                     0.888    Europe    French        0.044310
# Germany                    0.916    Europe    German        0.047868
# Italy                      0.873    Europe   Italian        0.035733
# Japan                      0.891      Asia       NaN        0.036222
# ...

# %% [markdown]
# ### Change Place of a Column

# %%
df.insert(2, 'GDP per capita', df.pop('GDP per capita'))

# %%
df
# Out:
#          Population  Gross Domestic Product  GDP per capita  Surface Area  \
# index
# Canada       35.467               1785387.0        0.050339     9984670.0
# France       63.951               2833687.0        0.044310      640679.0
# Germany      80.940               3874437.0        0.047868      357114.0
# Italy        60.665               2167744.0        0.035733      301336.0
# Japan       127.061               4602367.0        0.036222      377930.0
# UK           64.511               2950039.0        0.045729      242495.0
# USA         318.523              17348075.0        0.054464     9525067.0
# China      1500.000                     NaN             NaN           NaN
#
#          Human Development Index Continent Languages
# index
# Canada                     0.913   America       NaN
# France                     0.888    Europe    French
# Germany                    0.916    Europe    German
# Italy                      0.873    Europe   Italian
# ...

# %% [markdown]
# ## Statistic Functions

# %%
df.min(numeric_only=True).round(2)
# Out:
# Population                      35.47
# Gross Domestic Product     1785387.00
# GDP per capita                   0.04
# Surface Area                242495.00
# Human Development Index          0.87
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Population                 1.500000e+03
# Gross Domestic Product     1.734808e+07
# GDP per capita             5.446412e-02
# Surface Area               9.984670e+06
# Human Development Index    9.160000e-01
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# Population                 2.813898e+02
# Gross Domestic Product     5.080248e+06
# GDP per capita             4.495225e-02
# Surface Area               3.061327e+06
# Human Development Index    9.004286e-01
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Population                 7.272550e+01
# Gross Domestic Product     2.950039e+06
# GDP per capita             4.572924e-02
# Surface Area               3.779300e+05
# Human Development Index    9.070000e-01
# dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# # Working with CSV dataset

# %%
df = pd.read_csv('demo_data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## Data Overview

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.head(8)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# ...

# %%
df.tail(2)
# Out:
#        age     workclass  fnlwgt education  education-num      marital-status  \
# 32559   22       Private  201490   HS-grad              9       Never-married
# 32560   52  Self-emp-inc  287927   HS-grad              9  Married-civ-spouse
#
#             occupation relationship   race     sex  capital-gain  \
# 32559     Adm-clerical    Own-child  White    Male             0
# 32560  Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K

# %%
df.sample(5)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 26344   23           Private  100345     Bachelors             13
# 29847   49           Private  195612  Some-college             10
# 10287   67  Self-emp-not-inc  139960       7th-8th              4
# 10260   42  Self-emp-not-inc  212847       HS-grad              9
# 29786   41           Private  169104     Bachelors             13
#
#            marital-status       occupation relationship                race  \
# 26344       Never-married            Sales    Own-child               White
# 29847  Married-civ-spouse  Exec-managerial      Husband               White
# 10287  Married-civ-spouse     Craft-repair      Husband               White
# 10260       Never-married  Farming-fishing    Own-child               White
# 29786  Married-civ-spouse     Craft-repair      Husband  Asian-Pac-Islander
#
#         sex  capital-gain  capital-loss  hours-per-week native-country salary
# ...

# %%
df.sample(frac=0.0002)
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 16487   27   Private  205145       HS-grad              9  Married-civ-spouse
# 4360    21   Private   30039  Some-college             10       Never-married
# 23253   28   Private  392487       HS-grad              9  Married-civ-spouse
# 22666   21   Private  241367  Some-college             10       Never-married
# 12152   33   Private  150570     Bachelors             13  Married-civ-spouse
# 21908   36   Private   41017  Some-college             10  Married-civ-spouse
# 25922   32   Private  379412  Some-college             10       Never-married
#
#               occupation relationship   race     sex  capital-gain  \
# 16487  Machine-op-inspct      Husband  White    Male             0
# 4360      Prof-specialty    Own-child  White    Male             0
# 23253              Sales         Wife  White  Female             0
# 22666       Adm-clerical    Own-child  White    Male             0
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['capital-gain'].value_counts()
# Out:
# capital-gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: count, Length: 119, dtype: int64

# %%
df.education.value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
df.education.value_counts().plot(kind='barh',figsize=(14,7))
# Out:
# <Axes: ylabel='education'>

# %%
round(df.education.value_counts(normalize=True) * 100, 2)
# Out:
# education
# HS-grad         32.250238
# Some-college    22.391818
# Bachelors       16.446055
# Masters          5.291607
# Assoc-voc        4.244341
# 11th             3.608612
# Assoc-acdm       3.276926
# 10th             2.865391
# 7th-8th          1.983969
# Prof-school      1.768987
# 9th              1.578576
# 12th             1.329812
# Doctorate        1.268389
# 5th-6th          1.022696
# 1st-4th          0.515955
# Preschool        0.156629
# Name: proportion, dtype: float64

# %%
df.education.value_counts(normalize=True).round(3) * 100
# Out:
# education
# HS-grad         32.3
# Some-college    22.4
# Bachelors       16.4
# Masters          5.3
# Assoc-voc        4.2
# 11th             3.6
# Assoc-acdm       3.3
# 10th             2.9
# 7th-8th          2.0
# Prof-school      1.8
# 9th              1.6
# 12th             1.3
# Doctorate        1.3
# 5th-6th          1.0
# 1st-4th          0.5
# Preschool        0.2
# Name: proportion, dtype: float64

# %% [markdown]
# # Logical Filtering

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df[df.age >= 50]
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 1       50  Self-emp-not-inc   83311    Bachelors             13
# 3       53           Private  234721         11th              7
# 7       52  Self-emp-not-inc  209642      HS-grad              9
# 21      54           Private  302146      HS-grad              9
# 24      59           Private  109015      HS-grad              9
# ...    ...               ...     ...          ...            ...
# 32542   72                 ?  129912      HS-grad              9
# 32548   65  Self-emp-not-inc   99359  Prof-school             15
# 32554   53           Private  321865      Masters             14
# 32558   58           Private  151910      HS-grad              9
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
df[df.age >= 50].education.value_counts()
# Out:
# education
# HS-grad         2411
# Some-college    1217
# Bachelors        975
# Masters          502
# 7th-8th          326
# 10th             266
# Assoc-voc        230
# 11th             197
# Doctorate        175
# Prof-school      168
# 9th              165
# Assoc-acdm       151
# 5th-6th          116
# 1st-4th           75
# 12th              69
# Preschool         19
# Name: count, dtype: int64

# %%
df[df.age == 50].shape[0]
# Out:
# 602

# %%
for num in range(21):
    if num % 2 == 0 or num % 5 == 0:
        print(num)
# Out:
# 0
# 2
# 4
# 5
# 6
# 8
# 10
# 12
# 14
# 15
# 16
# 18
# 20

# %%
for num in range(21):
    if not num % 2 or not num % 5:
        print(num)
# Out:
# 0
# 2
# 4
# 5
# 6
# 8
# 10
# 12
# 14
# 15
# 16
# 18
# 20

# %% [markdown]
# ### AND

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df[(df.sex == 'Male') & (df['marital-status'] == 'Divorced')]
# Out:
#        age         workclass  fnlwgt  education  education-num marital-status  \
# 2       38           Private  215646    HS-grad              9       Divorced
# 28      39           Private  367260    HS-grad              9       Divorced
# 32      45           Private  386940  Bachelors             13       Divorced
# 53      50       Federal-gov  251585  Bachelors             13       Divorced
# 54      47      Self-emp-inc  109832    HS-grad              9       Divorced
# ...    ...               ...     ...        ...            ...            ...
# 32477   49                 ?  114648       12th              8       Divorced
# 32490   60                 ?  134152        9th              5       Divorced
# 32492   42  Self-emp-not-inc  217597    HS-grad              9       Divorced
# 32500   34           Private   60567       11th              7       Divorced
# 32523   30           Private   77266    HS-grad              9       Divorced
#
# ...

# %% [markdown]
# ### OR

# %%
df.age.min()
# Out:
# 17

# %%
df.age.max()
# Out:
# 90

# %%
df[(df.age <= 20) | (df.age >= 85)]
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 26      19   Private  168294       HS-grad              9       Never-married
# 31      20   Private  266015  Some-college             10       Never-married
# 37      19   Private  544091       HS-grad              9   Married-AF-spouse
# 51      18   Private  226956       HS-grad              9       Never-married
# 70      19   Private  101509  Some-college             10       Never-married
# ...    ...       ...     ...           ...            ...                 ...
# 32443   18   Private   41381       HS-grad              9       Never-married
# 32447   17   Private  117798          10th              6       Never-married
# 32459   85   Private   98611     Bachelors             13  Married-civ-spouse
# 32496   18   Private  436163          11th              7       Never-married
# 32512   20   Private  270436       HS-grad              9       Never-married
#
# ...

# %%
df[(df.age <= 20) | (df.age >= 85) | ((df.age >= 40) & (df.age <= 50))]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 6       49           Private  160187           9th              5
# 9       42           Private  159449     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# ...    ...               ...     ...           ...            ...
# 32547   43           Private  260761       HS-grad              9
# 32549   43         State-gov  255835  Some-college             10
# 32550   43  Self-emp-not-inc   27242  Some-college             10
# 32552   43           Private   84661     Assoc-voc             11
# 32557   40           Private  154374       HS-grad              9
#
#               marital-status         occupation    relationship  \
# 1         Married-civ-spouse    Exec-managerial         Husband
# ...

# %% [markdown]
# ### NOT

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df[df.education == 'Masters']
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 5       37           Private  284582   Masters             14
# 8       31           Private   45781   Masters             14
# 19      43  Self-emp-not-inc  292175   Masters             14
# 47      44           Private  128354   Masters             14
# 87      33           Private  202051   Masters             14
# ...    ...               ...     ...       ...            ...
# 32504   50           Private  208630   Masters             14
# 32513   46           Private   42972   Masters             14
# 32544   31           Private  199655   Masters             14
# 32553   32           Private  116138   Masters             14
# 32554   53           Private  321865   Masters             14
#
#            marital-status       occupation   relationship                race  \
# 5      Married-civ-spouse  Exec-managerial           Wife               White
# ...

# %%
df[~(df.education == 'Masters')]
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df[df.education != 'Masters']
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ### ISIN

# %%
'e' in 'Hello'
# Out:
# True

# %%
1 in [1, 'a']
# Out:
# True

# %%
df[df.education.isin(['10th', '11th', '12th'])]
# Out:
#        age    workclass  fnlwgt education  education-num      marital-status  \
# 3       53      Private  234721      11th              7  Married-civ-spouse
# 18      38      Private   28887      11th              7  Married-civ-spouse
# 23      43      Private  117037      11th              7  Married-civ-spouse
# 35      48      Private  242406      11th              7       Never-married
# 77      67            ?  212759      10th              6  Married-civ-spouse
# ...    ...          ...     ...       ...            ...                 ...
# 32515   66  Federal-gov   47358      10th              6  Married-civ-spouse
# 32522   58      Private  147707      11th              7  Married-civ-spouse
# 32526   32      Private  211349      10th              6  Married-civ-spouse
# 32535   22      Private  325033      12th              8       Never-married
# 32551   32      Private   34066      10th              6  Married-civ-spouse
#
# ...

# %%
df[~(df.education.isin(['10th', '11th', '12th']))]
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 4       28           Private  338409   Bachelors             13
# 5       37           Private  284582     Masters             14
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...
